# %% [markdown]
# Import necessary Libraries

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Select and Display an Image From Drive

# %%
test_image_path = "/content/drive/MyDrive/AI assessment/Bus/pexels-laker-6156582.jpg"
img = tf.keras.preprocessing.image.load_img(test_image_path, target_size = (224,224))
plt.imshow(img)

# %% [markdown]
# Lets load the Deep Learning Model

# %%
 mobile = tf.keras.applications.mobilenet.MobileNet() # Here we are using a pre-trained model

# %% [markdown]
# Preprocess our Test Image

# %%
test_image_path = "/content/drive/MyDrive/AI assessment/Bus/pexels-laker-6156582.jpg"

img = tf.keras.preprocessing.image.load_img(test_image_path, target_size = (224,224))

#Convert the Image into Array
img_arr = tf.keras.preprocessing.image.img_to_array(img)
print(img_arr.shape)

#For deep learning we need 1 more dimension
final_img = np.expand_dims(img_arr, axis=0)
final_img = tf.keras.applications.mobilenet.preprocess_input(final_img)

print(final_img.shape)
# Out:
# (224, 224, 3)
# (1, 224, 224, 3)

# %% [markdown]
# Test the Image with our Model

# %%
predictions = mobile.predict(final_img)

results = tf.keras.applications.imagenet_utils.decode_predictions(predictions)
print(results)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f3d83e29a70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [[('n04146614', 'school_bus', 0.9993957), ('n03895866', 'passenger_car', 0.0003736754), ('n03345487', 'fire_engine', 0.00011525033), ('n04487081', 'trolleybus', 4.7289574e-05), ('n03769881', 'minibus', 3.6843492e-05)]]

# %% [markdown]
#  Use Custom Model

# %%
#Easy to create model from https://teachablemachine.withgoogle.com

mobile = tf.keras.models.load_model('/content/drive/MyDrive/AI assessment/keras_model.h5')
class_names = ['Apple', 'Watermelon', 'Papaya']


test_image_path = "/content/drive/MyDrive/AI assessment/ Watermelon.jpg"
img = tf.keras.preprocessing.image.load_img(test_image_path, target_size = (224,224))
#Convert the Image into Array
img_arr = tf.keras.preprocessing.image.img_to_array(img)
#For deep learning we need 1 more dimension
final_img = np.expand_dims(img_arr, axis=0)
final_img = tf.keras.applications.mobilenet.preprocess_input(final_img)



predictions = mobile.predict(final_img)
score = tf.nn.softmax(predictions[0])
print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f3d83e075f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# This image most likely belongs to Watermelon with a 57.51 percent confidence.
